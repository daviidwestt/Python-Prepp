# %%
def fizzbuzz():
    
    for numero in range (1,101):
        if numero % 3 == 0:
            print("fizz")
        if numero % 5 == 0:
            print ("buz")
        elif numero % 3 == 0 and numero % 5 ==0:
            print("fizzbuzz")
        else:
            print(numero)
fizzbuzz()
# Out:
# 1
# 2
# fizz
# 3
# 4
# buz
# fizz
# 6
# 7
# 8
# fizz
# 9
# buz
# 11
# fizz
# 12
# 13
# 14
# fizz
# buz
# 16
# 17
# fizz
# 18
# 19
# buz
# fizz
# 21
# 22
# 23
# fizz
# 24
# buz
# 26
# fizz
# 27
# 28
# 29
# fizz
# buz
# 31
# 32
# fizz
# 33
# 34
# buz
# fizz
# 36
# 37
# 38
# fizz
# 39
# buz
# 41
# fizz
# 42
# 43
# 44
# fizz
# buz
# 46
# 47
# fizz
# 48
# 49
# buz
# fizz
# 51
# 52
# 53
# fizz
# 54
# buz
# 56
# fizz
# 57
# 58
# 59
# fizz
# buz
# 61
# 62
# fizz
# 63
# 64
# buz
# fizz
# 66
# 67
# 68
# fizz
# 69
# buz
# 71
# fizz
# 72
# 73
# 74
# fizz
# buz
# 76
# 77
# fizz
# 78
# 79
# buz
# fizz
# 81
# 82
# 83
# fizz
# 84
# buz
# 86
# fizz
# 87
# 88
# 89
# fizz
# buz
# 91
# 92
# fizz
# 93
# 94
# buz
# fizz
# 96
# 97
# 98
# fizz
# 99
# buz
